# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the Jupyter Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to **File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this Jupyter notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Write your Algorithm
# * [Step 6](#step6): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# Make sure that you've downloaded the required human and dog datasets:
#
# **Note: if you are using the Udacity workspace, you *DO NOT* need to re-download these - they can be found in the `/data` folder as noted in the cell below.**
#
# * Download the [dog dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip).  Unzip the folder and place it in this project's home directory, at the location `/dog_images`.
#
# * Download the [human dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/lfw.zip).  Unzip the folder and place it in the home directory, at location `/lfw`.
#
# *Note: If you are using a Windows machine, you are encouraged to use [7zip](http://www.7-zip.org/) to extract the folder.*
#
# In the code cell below, we save the file paths for both the human (LFW) dataset and dog dataset in the numpy arrays `human_files` and `dog_files`.

# %%
import numpy as np
from glob import glob

# load filenames for human and dog images
human_files = np.array(glob("data/lfw/*/*"))
dog_files = np.array(glob("data/dogImages/*/*/*"))

# print number of images in each dataset
print('There are %d total human images.' % len(human_files))
print('There are %d total dog images.' % len(dog_files))
# Out:
# There are 13233 total human images.
# There are 8351 total dog images.

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# In this section, we use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.
#
# OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.  In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[0])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 2

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.

# %% [markdown]
# __Answer:__
# (You can print out your results and/or write your percentages in this cell)

# %%
from tqdm import tqdm

human_files_short = human_files[:100]
dog_files_short = dog_files[:100]

#-#-# Do NOT modify the code above this line. #-#-#

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.

hc = 0
dc = 0

for i in tqdm(range(100)) : 
    if face_detector(human_files_short[i]) : hc += 1

for i in tqdm(range(100)) : 
    if face_detector(dog_files_short[i]) : dc += 1
    
print("Human Accuracy (%) : ", hc, " %")
print("Dog Accuracy (%) : ", dc, " %")
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 84.78it/s]
# 100%|██████████| 100/100 [00:03<00:00, 28.41it/s]
# Human Accuracy (%) :  98  %
# Dog Accuracy (%) :  7  %

# %% [markdown]
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %%
### (Optional) 
### TODO: Test performance of anotherface detection algorithm.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a [pre-trained model](http://pytorch.org/docs/master/torchvision/models.html) to detect dogs in images.
#
# ### Obtain Pre-trained VGG-16 Model
#
# The code cell below downloads the VGG-16 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
import torch
import torchvision.models as models

# define VGG16 model
VGG16 = models.vgg16(pretrained=True)

# check if CUDA is available
use_cuda = torch.cuda.is_available()

# move model to GPU if CUDA is available
if use_cuda:
    VGG16 = VGG16.cuda()
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /home/opener/.cache/torch/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:38<00:00, 14.3MB/s]

# %% [markdown]
# Given an image, this pre-trained VGG-16 model returns a prediction (derived from the 1000 possible categories in ImageNet) for the object that is contained in the image.

# %% [markdown]
# ### (IMPLEMENTATION) Making Predictions with a Pre-trained Model
#
# In the next code cell, you will write a function that accepts a path to an image (such as `'dogImages/train/001.Affenpinscher/Affenpinscher_00001.jpg'`) as input and returns the index corresponding to the ImageNet class that is predicted by the pre-trained VGG-16 model.  The output should always be an integer between 0 and 999, inclusive.
#
# Before writing the function, make sure that you take the time to learn  how to appropriately pre-process tensors for pre-trained models in the [PyTorch documentation](http://pytorch.org/docs/stable/torchvision/models.html).

# %%
from PIL import Image
import torchvision.transforms as transforms

def VGG16_predict(img_path):
    '''
    Use pre-trained VGG-16 model to obtain index corresponding to 
    predicted ImageNet class for image at specified path
    
    Args:
        img_path: path to an image
        
    Returns:
        Index corresponding to VGG-16 model's prediction
    '''
    
    ## TODO: Complete the function.
    ## Load and pre-process an image from the given img_path
    ## Return the *index* of the predicted class for that image
    in_transform = transforms.Compose([transforms.Resize((224, 224)),
                                    transforms.ToTensor(),
                                    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                         std=[0.229, 0.224, 0.225])])
    
    img = Image.open(img_path).convert('RGB')
    img = in_transform(img)[:3, :, :].unsqueeze(0)

    if use_cuda:
        img = img.cuda()
        
    prediction = VGG16(img)
    _, idx = torch.max(prediction, 1)
    
    return idx.item()

# %% [markdown]
# ### (IMPLEMENTATION) Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained VGG-16 model, we need only check if the pre-trained model predicts an index between 151 and 268 (inclusive).
#
# Use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    ## TODO: Complete the function.
    from_idx = 151
    to_idx = 268
    
    predicted_result = VGG16_predict(img_path)
    
    is_dog_detected = True if predicted_result >= from_idx and predicted_result <= to_idx else False
    return is_dog_detected # true/false

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 2:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?

# %% [markdown]
# __Answer:__

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.

hc = 0
dc = 0

for i in tqdm(range(100)) : 
    if dog_detector(human_files_short[i]) : hc += 1

for i in tqdm(range(100)) : 
    if dog_detector(dog_files_short[i]) : dc += 1
    
print("Dog detected in human_files_short (%) : ", hc, " %")
print("Dog deteceted in dog_files_short (%) : ", dc, " %")
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 34.60it/s]
# 100%|██████████| 100/100 [00:00<00:00, 102.60it/s]
# Dog detected in human_files_short (%) :  1  %
# Dog deteceted in dog_files_short (%) :  98  %

# %% [markdown]
# We suggest VGG-16 as a potential network to detect dog images in your algorithm, but you are free to explore other pre-trained networks (such as [Inception-v3](http://pytorch.org/docs/master/torchvision/models.html#inception-v3), [ResNet-50](http://pytorch.org/docs/master/torchvision/models.html#id3), etc).  Please use the code cell below to test other pre-trained PyTorch models.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %%
### (Optional) 
### TODO: Report the performance of another pre-trained network.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 10%.  In Step 4 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have trouble distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dog_images/train`, `dog_images/valid`, and `dog_images/test`, respectively).  You may find [this documentation on custom datasets](http://pytorch.org/docs/stable/torchvision/datasets.html) to be a useful resource.  If you are interested in augmenting your training and/or validation data, check out the wide variety of [transforms](http://pytorch.org/docs/stable/torchvision/transforms.html?highlight=transform)!

# %%
import os
from torchvision import datasets

### TODO: Write data loaders for training, validation, and test sets
## Specify appropriate transforms, and batch_sizes

root_dir = 'data/dogImages/'
train_dir = os.path.join(root_dir, 'train/')
valid_dir = os.path.join(root_dir, 'valid/')
test_dir = os.path.join(root_dir, 'test/')

normalization = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])

train_transform = transforms.Compose([transforms.Resize(256),
                                      transforms.RandomResizedCrop(224),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.RandomRotation(10),
                                      transforms.ToTensor(),
                                      normalization])

valid_transform = transforms.Compose([transforms.Resize(256), 
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      normalization])

test_transform  = transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      normalization])

batch_size = 20
num_workers = 0

train_data = datasets.ImageFolder(train_dir, transform=train_transform)
valid_data = datasets.ImageFolder(valid_dir, transform=valid_transform)
test_data = datasets.ImageFolder(test_dir, transform=test_transform)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=num_workers)

loaders_scratch = {"train" : train_loader, "valid" : valid_loader, "test" : test_loader}

# %% [markdown]
# **Question 3:** Describe your chosen procedure for preprocessing the data.
# - How does your code resize the images (by cropping, stretching, etc)?  What size did you pick for the input tensor, and why?
# - Did you decide to augment the dataset?  If so, how (through translations, flips, rotations, etc)?  If not, why not?

# %% [markdown]
# **Answer**:

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  Use the template in the code cell below.

# %%
import torch.nn as nn
import torch.nn.functional as F

from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
# define the CNN architecture
class Net(nn.Module):
    ### TODO: choose an architecture, and complete the class
    def __init__(self):
        super(Net, self).__init__()
        ## Define CNN layers
        self.conv1 = nn.Conv2d( 3, 32, 3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, 3, stride=1, padding=1)
        self.conv3 = nn.Conv2d( 64, 128, 3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(128, 128, 3, stride=1, padding=1)

        # Pooling
        self.pool = nn.MaxPool2d(2, 2)
        
        # Define fully connected layers
        self.fc1 = nn.Linear(14*14*128, 4096)
        self.fc2 = nn.Linear(4096, 134)
        
        # drop-out
        self.dropout = nn.Dropout(0.25)
        
    def forward(self, x):
         ## Define forward behavior
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        x = F.relu(self.conv3(x))
        x = self.pool(x)
        x = F.relu(self.conv4(x))
        x = self.pool(x)
        
        # flatten
        x = x.view(-1, 14*14*128)
        
        x = self.dropout(x)
        
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        
        x = self.fc2(x)
        return x

#-#-# You so NOT have to modify the code below this line. #-#-#

# instantiate the CNN
model_scratch = Net()

# move tensors to GPU if CUDA is available
if use_cuda:
    model_scratch.cuda()

# %% [markdown]
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.

# %% [markdown]
# __Answer:__

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/stable/optim.html).  Save the chosen loss function as `criterion_scratch`, and the optimizer as `optimizer_scratch` below.

# %%
import torch.optim as optim

### TODO: select loss function
criterion_scratch = nn.CrossEntropyLoss()

### TODO: select optimizer
optimizer_scratch = optim.SGD(model_scratch.parameters(), lr = 0.03)

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_scratch.pt'`.

# %%
def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path):
    """returns trained model"""
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf 
    
    for epoch in range(1, n_epochs+1):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        ###################
        # train the model #
        ###################
        model.train()
        for batch_idx, (data, target) in enumerate(loaders['train']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## find the loss and update the model parameters accordingly
            ## record the average training loss, using something like
            ## train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            optimizer.zero_grad()
            
            output = model(data)
            
            # calculate loss
            loss = criterion(output, target)
            
            # back prop
            loss.backward()
            
            # grad
            optimizer.step()
            
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
            if batch_idx % 100 == 0:
                print('Epoch %d, Batch %d loss: %.6f' %
                  (epoch, batch_idx + 1, train_loss))
        ######################    
        # validate the model #
        ######################
        model.eval()
        for batch_idx, (data, target) in enumerate(loaders['valid']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## update the average validation loss
            output = model(data)
            loss = criterion(output, target)
            valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))
            
        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
            epoch, 
            train_loss,
            valid_loss
            ))
        
        ## TODO: save the model if validation loss has decreased
        if valid_loss < valid_loss_min:
            torch.save(model.state_dict(), save_path)
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            valid_loss_min = valid_loss    
    # return trained model
    return model


# train the model
model_scratch = train(100, loaders_scratch, model_scratch, optimizer_scratch, 
                      criterion_scratch, use_cuda, 'model_scratch.pt')

# load the model that got the best validation accuracy
model_scratch.load_state_dict(torch.load('model_scratch.pt'))
# Out:
# Epoch 1, Batch 1 loss: 4.897199
# Epoch 1, Batch 101 loss: 4.894054
# Epoch 1, Batch 201 loss: 4.888819
# Epoch 1, Batch 301 loss: 4.883782
# Epoch: 1 	Training Loss: 4.881306 	Validation Loss: 4.843602
# Validation loss decreased (inf --> 4.843602).  Saving model ...
# Epoch 2, Batch 1 loss: 4.708196
# Epoch 2, Batch 101 loss: 4.832168
# Epoch 2, Batch 201 loss: 4.817117
# Epoch 2, Batch 301 loss: 4.794793
# Epoch: 2 	Training Loss: 4.782994 	Validation Loss: 4.639330
# Validation loss decreased (4.843602 --> 4.639330).  Saving model ...
# Epoch 3, Batch 1 loss: 4.719308
# Epoch 3, Batch 101 loss: 4.661863
# Epoch 3, Batch 201 loss: 4.649303
# Epoch 3, Batch 301 loss: 4.635686
# Epoch: 3 	Training Loss: 4.634811 	Validation Loss: 4.548691
# Validation loss decreased (4.639330 --> 4.548691).  Saving model ...
# Epoch 4, Batch 1 loss: 4.442496
# Epoch 4, Batch 101 loss: 4.577920
# Epoch 4, Batch 201 loss: 4.559283
# Epoch 4, Batch 301 loss: 4.560988
# Epoch: 4 	Training Loss: 4.561513 	Validation Loss: 4.462374
# Validation loss decreased (4.548691 --> 4.462374).  Saving model ...
# Epoch 5, Batch 1 loss: 4.521266
# Epoch 5, Batch 101 loss: 4.501855
# Epoch 5, Batch 201 loss: 4.501429
# Epoch 5, Batch 301 loss: 4.501233
# Epoch: 5 	Training Loss: 4.496733 	Validation Loss: 4.405195
# Validation loss decreased (4.462374 --> 4.405195).  Saving model ...
# Epoch 6, Batch 1 loss: 4.550935
# Epoch 6, Batch 101 loss: 4.439871
# Epoch 6, Batch 201 loss: 4.436230
# Epoch 6, Batch 301 loss: 4.437193
# Epoch: 6 	Training Loss: 4.440281 	Validation Loss: 4.338713
# Validation loss decreased (4.405195 --> 4.338713).  Saving model ...
# Epoch 7, Batch 1 loss: 4.203551
# Epoch 7, Batch 101 loss: 4.408795
# Epoch 7, Batch 201 loss: 4.400328
# Epoch 7, Batch 301 loss: 4.402843
# Epoch: 7 	Training Loss: 4.395895 	Validation Loss: 4.305701
# Validation loss decreased (4.338713 --> 4.305701).  Saving model ...
# Epoch 8, Batch 1 loss: 4.477294
# Epoch 8, Batch 101 loss: 4.287040
# Epoch 8, Batch 201 loss: 4.334554
# Epoch 8, Batch 301 loss: 4.321897
# Epoch: 8 	Training Loss: 4.324175 	Validation Loss: 4.208191
# Validation loss decreased (4.305701 --> 4.208191).  Saving model ...
# Epoch 9, Batch 1 loss: 4.181239
# Epoch 9, Batch 101 loss: 4.309324
# Epoch 9, Batch 201 loss: 4.293887
# Epoch 9, Batch 301 loss: 4.285346
# Epoch: 9 	Training Loss: 4.284098 	Validation Loss: 4.151242
# Validation loss decreased (4.208191 --> 4.151242).  Saving model ...
# Epoch 10, Batch 1 loss: 4.179276
# Epoch 10, Batch 101 loss: 4.221610
# Epoch 10, Batch 201 loss: 4.210279
# Epoch 10, Batch 301 loss: 4.211431
# Epoch: 10 	Training Loss: 4.214599 	Validation Loss: 4.136842
# Validation loss decreased (4.151242 --> 4.136842).  Saving model ...
# Epoch 11, Batch 1 loss: 4.316503
# Epoch 11, Batch 101 loss: 4.166229
# Epoch 11, Batch 201 loss: 4.170156
# Epoch 11, Batch 301 loss: 4.174862
# Epoch: 11 	Training Loss: 4.171333 	Validation Loss: 4.264103
# Epoch 12, Batch 1 loss: 4.453912
# Epoch 12, Batch 101 loss: 4.068495
# Epoch 12, Batch 201 loss: 4.101440
# Epoch 12, Batch 301 loss: 4.094382
# Epoch: 12 	Training Loss: 4.091137 	Validation Loss: 3.964369
# Validation loss decreased (4.136842 --> 3.964369).  Saving model ...
# Epoch 13, Batch 1 loss: 3.896480
# Epoch 13, Batch 101 loss: 4.018117
# Epoch 13, Batch 201 loss: 4.020167
# Epoch 13, Batch 301 loss: 4.023350
# Epoch: 13 	Training Loss: 4.032367 	Validation Loss: 3.936080
# Validation loss decreased (3.964369 --> 3.936080).  Saving model ...
# Epoch 14, Batch 1 loss: 4.078273
# Epoch 14, Batch 101 loss: 3.995964
# Epoch 14, Batch 201 loss: 3.974145
# Epoch 14, Batch 301 loss: 3.978084
# Epoch: 14 	Training Loss: 3.973137 	Validation Loss: 3.770351
# Validation loss decreased (3.936080 --> 3.770351).  Saving model ...
# Epoch 15, Batch 1 loss: 4.115794
# Epoch 15, Batch 101 loss: 3.911249
# Epoch 15, Batch 201 loss: 3.905010
# Epoch 15, Batch 301 loss: 3.919996
# Epoch: 15 	Training Loss: 3.914298 	Validation Loss: 3.787194
# Epoch 16, Batch 1 loss: 3.734816
# Epoch 16, Batch 101 loss: 3.833779
# Epoch 16, Batch 201 loss: 3.849349
# Epoch 16, Batch 301 loss: 3.874723
# Epoch: 16 	Training Loss: 3.882935 	Validation Loss: 3.743902
# Validation loss decreased (3.770351 --> 3.743902).  Saving model ...
# Epoch 17, Batch 1 loss: 3.562548
# Epoch 17, Batch 101 loss: 3.749815
# Epoch 17, Batch 201 loss: 3.795299
# Epoch 17, Batch 301 loss: 3.809913
# Epoch: 17 	Training Loss: 3.813802 	Validation Loss: 3.634024
# Validation loss decreased (3.743902 --> 3.634024).  Saving model ...
# Epoch 18, Batch 1 loss: 3.621997
# Epoch 18, Batch 101 loss: 3.747351
# Epoch 18, Batch 201 loss: 3.737710
# Epoch 18, Batch 301 loss: 3.752801
# Epoch: 18 	Training Loss: 3.758108 	Validation Loss: 3.691753
# Epoch 19, Batch 1 loss: 3.518342
# Epoch 19, Batch 101 loss: 3.659523
# Epoch 19, Batch 201 loss: 3.684809
# Epoch 19, Batch 301 loss: 3.702045
# Epoch: 19 	Training Loss: 3.707511 	Validation Loss: 3.550415
# Validation loss decreased (3.634024 --> 3.550415).  Saving model ...
# Epoch 20, Batch 1 loss: 3.471815
# Epoch 20, Batch 101 loss: 3.680231
# Epoch 20, Batch 201 loss: 3.699540
# Epoch 20, Batch 301 loss: 3.685922
# Epoch: 20 	Training Loss: 3.681695 	Validation Loss: 3.495649
# Validation loss decreased (3.550415 --> 3.495649).  Saving model ...
# Epoch 21, Batch 1 loss: 3.398694
# Epoch 21, Batch 101 loss: 3.518082
# Epoch 21, Batch 201 loss: 3.594398
# Epoch 21, Batch 301 loss: 3.612280
# Epoch: 21 	Training Loss: 3.621304 	Validation Loss: 3.420470
# Validation loss decreased (3.495649 --> 3.420470).  Saving model ...
# Epoch 22, Batch 1 loss: 3.334356
# Epoch 22, Batch 101 loss: 3.482993
# Epoch 22, Batch 201 loss: 3.541064
# Epoch 22, Batch 301 loss: 3.570547
# Epoch: 22 	Training Loss: 3.568805 	Validation Loss: 3.350139
# Validation loss decreased (3.420470 --> 3.350139).  Saving model ...
# Epoch 23, Batch 1 loss: 3.818182
# Epoch 23, Batch 101 loss: 3.442315
# Epoch 23, Batch 201 loss: 3.481225
# Epoch 23, Batch 301 loss: 3.507089
# Epoch: 23 	Training Loss: 3.520317 	Validation Loss: 3.321134
# Validation loss decreased (3.350139 --> 3.321134).  Saving model ...
# Epoch 24, Batch 1 loss: 3.611804
# Epoch 24, Batch 101 loss: 3.397202
# Epoch 24, Batch 201 loss: 3.431088
# Epoch 24, Batch 301 loss: 3.470626
# Epoch: 24 	Training Loss: 3.467510 	Validation Loss: 3.324669
# Epoch 25, Batch 1 loss: 3.418122
# Epoch 25, Batch 101 loss: 3.362330
# Epoch 25, Batch 201 loss: 3.386503
# Epoch 25, Batch 301 loss: 3.406692
# Epoch: 25 	Training Loss: 3.411250 	Validation Loss: 3.137750
# Validation loss decreased (3.321134 --> 3.137750).  Saving model ...
# Epoch 26, Batch 1 loss: 3.190328
# Epoch 26, Batch 101 loss: 3.288015
# Epoch 26, Batch 201 loss: 3.350616
# Epoch 26, Batch 301 loss: 3.377997
# Epoch: 26 	Training Loss: 3.391852 	Validation Loss: 3.105561
# Validation loss decreased (3.137750 --> 3.105561).  Saving model ...
# Epoch 27, Batch 1 loss: 3.177044
# Epoch 27, Batch 101 loss: 3.241231
# Epoch 27, Batch 201 loss: 3.277588
# Epoch 27, Batch 301 loss: 3.276999
# Epoch: 27 	Training Loss: 3.278849 	Validation Loss: 3.131087
# Epoch 28, Batch 1 loss: 2.934527
# Epoch 28, Batch 101 loss: 3.185727
# Epoch 28, Batch 201 loss: 3.217084
# Epoch 28, Batch 301 loss: 3.266750
# Epoch: 28 	Training Loss: 3.270577 	Validation Loss: 3.010087
# Validation loss decreased (3.105561 --> 3.010087).  Saving model ...
# Epoch 29, Batch 1 loss: 2.587354
# Epoch 29, Batch 101 loss: 3.122326
# Epoch 29, Batch 201 loss: 3.181812
# Epoch 29, Batch 301 loss: 3.191958
# Epoch: 29 	Training Loss: 3.188581 	Validation Loss: 2.875473
# Validation loss decreased (3.010087 --> 2.875473).  Saving model ...
# Epoch 30, Batch 1 loss: 2.635637
# Epoch 30, Batch 101 loss: 3.098530
# Epoch 30, Batch 201 loss: 3.103843
# Epoch 30, Batch 301 loss: 3.135402
# Epoch: 30 	Training Loss: 3.145170 	Validation Loss: 2.806755
# Validation loss decreased (2.875473 --> 2.806755).  Saving model ...
# Epoch 31, Batch 1 loss: 2.599424
# Epoch 31, Batch 101 loss: 3.043494
# Epoch 31, Batch 201 loss: 3.074659
# Epoch 31, Batch 301 loss: 3.089886
# Epoch: 31 	Training Loss: 3.101300 	Validation Loss: 2.857203
# Epoch 32, Batch 1 loss: 2.576153
# Epoch 32, Batch 101 loss: 2.992834
# Epoch 32, Batch 201 loss: 3.002019
# Epoch 32, Batch 301 loss: 3.036583
# Epoch: 32 	Training Loss: 3.050298 	Validation Loss: 2.778648
# Validation loss decreased (2.806755 --> 2.778648).  Saving model ...
# Epoch 33, Batch 1 loss: 3.213895
# Epoch 33, Batch 101 loss: 2.907665
# Epoch 33, Batch 201 loss: 2.930336
# Epoch 33, Batch 301 loss: 2.950525
# Epoch: 33 	Training Loss: 2.958256 	Validation Loss: 2.684564
# Validation loss decreased (2.778648 --> 2.684564).  Saving model ...
# Epoch 34, Batch 1 loss: 2.321392
# Epoch 34, Batch 101 loss: 2.863860
# Epoch 34, Batch 201 loss: 2.891626
# Epoch 34, Batch 301 loss: 2.933868
# Epoch: 34 	Training Loss: 2.932483 	Validation Loss: 2.634251
# Validation loss decreased (2.684564 --> 2.634251).  Saving model ...
# Epoch 35, Batch 1 loss: 2.907622
# Epoch 35, Batch 101 loss: 2.834108
# Epoch 35, Batch 201 loss: 2.870346
# Epoch 35, Batch 301 loss: 2.878529
# Epoch: 35 	Training Loss: 2.883015 	Validation Loss: 2.657009
# Epoch 36, Batch 1 loss: 2.531118
# Epoch 36, Batch 101 loss: 2.737288
# Epoch 36, Batch 201 loss: 2.814505
# Epoch 36, Batch 301 loss: 2.824573
# Epoch: 36 	Training Loss: 2.817075 	Validation Loss: 2.617145
# Validation loss decreased (2.634251 --> 2.617145).  Saving model ...
# Epoch 37, Batch 1 loss: 2.392225
# Epoch 37, Batch 101 loss: 2.728555
# Epoch 37, Batch 201 loss: 2.739102
# Epoch 37, Batch 301 loss: 2.774171
# Epoch: 37 	Training Loss: 2.783690 	Validation Loss: 2.460057
# Validation loss decreased (2.617145 --> 2.460057).  Saving model ...
# Epoch 38, Batch 1 loss: 2.597221
# Epoch 38, Batch 101 loss: 2.611254
# Epoch 38, Batch 201 loss: 2.668070
# Epoch 38, Batch 301 loss: 2.704776
# Epoch: 38 	Training Loss: 2.704784 	Validation Loss: 2.446984
# Validation loss decreased (2.460057 --> 2.446984).  Saving model ...
# Epoch 39, Batch 1 loss: 3.247622
# Epoch 39, Batch 101 loss: 2.628133
# Epoch 39, Batch 201 loss: 2.672791
# Epoch 39, Batch 301 loss: 2.699194
# Epoch: 39 	Training Loss: 2.706474 	Validation Loss: 2.251462
# Validation loss decreased (2.446984 --> 2.251462).  Saving model ...
# Epoch 40, Batch 1 loss: 2.107632
# Epoch 40, Batch 101 loss: 2.567652
# Epoch 40, Batch 201 loss: 2.575904
# Epoch 40, Batch 301 loss: 2.610221
# Epoch: 40 	Training Loss: 2.620407 	Validation Loss: 2.363328
# Epoch 41, Batch 1 loss: 2.543194
# Epoch 41, Batch 101 loss: 2.505837
# Epoch 41, Batch 201 loss: 2.527919
# Epoch 41, Batch 301 loss: 2.547501
# Epoch: 41 	Training Loss: 2.550086 	Validation Loss: 2.214417
# Validation loss decreased (2.251462 --> 2.214417).  Saving model ...
# Epoch 42, Batch 1 loss: 2.537879
# Epoch 42, Batch 101 loss: 2.501513
# Epoch 42, Batch 201 loss: 2.508764
# Epoch 42, Batch 301 loss: 2.533499
# Epoch: 42 	Training Loss: 2.530230 	Validation Loss: 2.195544
# Validation loss decreased (2.214417 --> 2.195544).  Saving model ...
# Epoch 43, Batch 1 loss: 3.118309
# Epoch 43, Batch 101 loss: 2.394539
# Epoch 43, Batch 201 loss: 2.447963
# Epoch 43, Batch 301 loss: 2.466921
# Epoch: 43 	Training Loss: 2.462329 	Validation Loss: 2.194310
# Validation loss decreased (2.195544 --> 2.194310).  Saving model ...
# Epoch 44, Batch 1 loss: 2.697075
# Epoch 44, Batch 101 loss: 2.451391
# Epoch 44, Batch 201 loss: 2.432992
# Epoch 44, Batch 301 loss: 2.449566
# Epoch: 44 	Training Loss: 2.459949 	Validation Loss: 2.184220
# Validation loss decreased (2.194310 --> 2.184220).  Saving model ...
# Epoch 45, Batch 1 loss: 2.270633
# Epoch 45, Batch 101 loss: 2.370362
# Epoch 45, Batch 201 loss: 2.374353
# Epoch 45, Batch 301 loss: 2.402867
# Epoch: 45 	Training Loss: 2.409965 	Validation Loss: 1.970487
# Validation loss decreased (2.184220 --> 1.970487).  Saving model ...
# Epoch 46, Batch 1 loss: 1.948548
# Epoch 46, Batch 101 loss: 2.331512
# Epoch 46, Batch 201 loss: 2.337206
# Epoch 46, Batch 301 loss: 2.362046
# Epoch: 46 	Training Loss: 2.379338 	Validation Loss: 2.115682
# Epoch 47, Batch 1 loss: 2.422542
# Epoch 47, Batch 101 loss: 2.235257
# Epoch 47, Batch 201 loss: 2.299965
# Epoch 47, Batch 301 loss: 2.321251
# Epoch: 47 	Training Loss: 2.326391 	Validation Loss: 1.905772
# Validation loss decreased (1.970487 --> 1.905772).  Saving model ...
# Epoch 48, Batch 1 loss: 2.003259
# Epoch 48, Batch 101 loss: 2.168401
# Epoch 48, Batch 201 loss: 2.240447
# Epoch 48, Batch 301 loss: 2.290328
# Epoch: 48 	Training Loss: 2.299905 	Validation Loss: 1.887265
# Validation loss decreased (1.905772 --> 1.887265).  Saving model ...
# Epoch 49, Batch 1 loss: 2.287769
# Epoch 49, Batch 101 loss: 2.223466
# Epoch 49, Batch 201 loss: 2.217891
# Epoch 49, Batch 301 loss: 2.253717
# Epoch: 49 	Training Loss: 2.257407 	Validation Loss: 1.945267
# Epoch 50, Batch 1 loss: 2.294612
# Epoch 50, Batch 101 loss: 2.174477
# Epoch 50, Batch 201 loss: 2.223456
# Epoch 50, Batch 301 loss: 2.233609
# Epoch: 50 	Training Loss: 2.239660 	Validation Loss: 1.936794
# Epoch 51, Batch 1 loss: 2.544564
# Epoch 51, Batch 101 loss: 2.083672
# Epoch 51, Batch 201 loss: 2.131363
# Epoch 51, Batch 301 loss: 2.154659
# Epoch: 51 	Training Loss: 2.173181 	Validation Loss: 1.910507
# Epoch 52, Batch 1 loss: 2.353895
# Epoch 52, Batch 101 loss: 2.056166
# Epoch 52, Batch 201 loss: 2.127150
# Epoch 52, Batch 301 loss: 2.141727
# Epoch: 52 	Training Loss: 2.137174 	Validation Loss: 1.781189
# Validation loss decreased (1.887265 --> 1.781189).  Saving model ...
# Epoch 53, Batch 1 loss: 1.299316
# Epoch 53, Batch 101 loss: 1.959469
# Epoch 53, Batch 201 loss: 2.054167
# Epoch 53, Batch 301 loss: 2.089749
# Epoch: 53 	Training Loss: 2.112364 	Validation Loss: 1.712196
# Validation loss decreased (1.781189 --> 1.712196).  Saving model ...
# Epoch 54, Batch 1 loss: 1.565933
# Epoch 54, Batch 101 loss: 2.054439
# Epoch 54, Batch 201 loss: 2.085377
# Epoch 54, Batch 301 loss: 2.110935
# Epoch: 54 	Training Loss: 2.103702 	Validation Loss: 1.753020
# Epoch 55, Batch 1 loss: 2.314770
# Epoch 55, Batch 101 loss: 1.970224
# Epoch 55, Batch 201 loss: 2.003830
# Epoch 55, Batch 301 loss: 2.036533
# Epoch: 55 	Training Loss: 2.034266 	Validation Loss: 1.707330
# Validation loss decreased (1.712196 --> 1.707330).  Saving model ...
# Epoch 56, Batch 1 loss: 1.989896
# Epoch 56, Batch 101 loss: 1.952591
# Epoch 56, Batch 201 loss: 2.025121
# Epoch 56, Batch 301 loss: 2.043159
# Epoch: 56 	Training Loss: 2.050375 	Validation Loss: 1.687286
# Validation loss decreased (1.707330 --> 1.687286).  Saving model ...
# Epoch 57, Batch 1 loss: 2.053855
# Epoch 57, Batch 101 loss: 1.912079
# Epoch 57, Batch 201 loss: 1.927749
# Epoch 57, Batch 301 loss: 1.954479
# Epoch: 57 	Training Loss: 1.967638 	Validation Loss: 1.604979
# Validation loss decreased (1.687286 --> 1.604979).  Saving model ...
# Epoch 58, Batch 1 loss: 2.084814
# Epoch 58, Batch 101 loss: 1.913965
# Epoch 58, Batch 201 loss: 2.001698
# Epoch 58, Batch 301 loss: 1.986079
# Epoch: 58 	Training Loss: 1.984131 	Validation Loss: 1.551031
# Validation loss decreased (1.604979 --> 1.551031).  Saving model ...
# Epoch 59, Batch 1 loss: 0.973172
# Epoch 59, Batch 101 loss: 1.850681
# Epoch 59, Batch 201 loss: 1.890658
# Epoch 59, Batch 301 loss: 1.914212
# Epoch: 59 	Training Loss: 1.907185 	Validation Loss: 1.552196
# Epoch 60, Batch 1 loss: 0.942311
# Epoch 60, Batch 101 loss: 1.841774
# Epoch 60, Batch 201 loss: 1.893821
# Epoch 60, Batch 301 loss: 1.923968
# Epoch: 60 	Training Loss: 1.912994 	Validation Loss: 1.483521
# Validation loss decreased (1.551031 --> 1.483521).  Saving model ...
# Epoch 61, Batch 1 loss: 2.737919
# Epoch 61, Batch 101 loss: 1.806793
# Epoch 61, Batch 201 loss: 1.852019
# Epoch 61, Batch 301 loss: 1.886072
# Epoch: 61 	Training Loss: 1.898869 	Validation Loss: 1.608684
# Epoch 62, Batch 1 loss: 1.626785
# Epoch 62, Batch 101 loss: 1.820163
# Epoch 62, Batch 201 loss: 1.834854
# Epoch 62, Batch 301 loss: 1.867605
# Epoch: 62 	Training Loss: 1.874196 	Validation Loss: 1.567925
# Epoch 63, Batch 1 loss: 2.196586
# Epoch 63, Batch 101 loss: 1.778597
# Epoch 63, Batch 201 loss: 1.810462
# Epoch 63, Batch 301 loss: 1.830829
# Epoch: 63 	Training Loss: 1.833044 	Validation Loss: 1.522346
# Epoch 64, Batch 1 loss: 2.983284
# Epoch 64, Batch 101 loss: 1.727046
# Epoch 64, Batch 201 loss: 1.788912
# Epoch 64, Batch 301 loss: 1.814657
# Epoch: 64 	Training Loss: 1.836291 	Validation Loss: 1.620922
# Epoch 65, Batch 1 loss: 1.953796
# Epoch 65, Batch 101 loss: 1.746441
# Epoch 65, Batch 201 loss: 1.777269
# Epoch 65, Batch 301 loss: 1.804810
# Epoch: 65 	Training Loss: 1.805079 	Validation Loss: 1.439068
# Validation loss decreased (1.483521 --> 1.439068).  Saving model ...
# Epoch 66, Batch 1 loss: 1.689210
# Epoch 66, Batch 101 loss: 1.718929
# Epoch 66, Batch 201 loss: 1.762825
# Epoch 66, Batch 301 loss: 1.766910
# Epoch: 66 	Training Loss: 1.794532 	Validation Loss: 1.539129
# Epoch 67, Batch 1 loss: 1.804574
# Epoch 67, Batch 101 loss: 1.773237
# Epoch 67, Batch 201 loss: 1.748569
# Epoch 67, Batch 301 loss: 1.767233
# Epoch: 67 	Training Loss: 1.780710 	Validation Loss: 1.391624
# Validation loss decreased (1.439068 --> 1.391624).  Saving model ...
# Epoch 68, Batch 1 loss: 1.249086
# Epoch 68, Batch 101 loss: 1.693037
# Epoch 68, Batch 201 loss: 1.714227
# Epoch 68, Batch 301 loss: 1.757811
# Epoch: 68 	Training Loss: 1.769712 	Validation Loss: 1.431856
# Epoch 69, Batch 1 loss: 1.819095
# Epoch 69, Batch 101 loss: 1.656318
# Epoch 69, Batch 201 loss: 1.691268
# Epoch 69, Batch 301 loss: 1.694461
# Epoch: 69 	Training Loss: 1.705320 	Validation Loss: 1.451794
# Epoch 70, Batch 1 loss: 1.255594
# Epoch 70, Batch 101 loss: 1.581766
# Epoch 70, Batch 201 loss: 1.639099
# Epoch 70, Batch 301 loss: 1.664947
# Epoch: 70 	Training Loss: 1.677803 	Validation Loss: 1.394279
# Epoch 71, Batch 1 loss: 1.198956
# Epoch 71, Batch 101 loss: 1.576206
# Epoch 71, Batch 201 loss: 1.636992
# Epoch 71, Batch 301 loss: 1.656996
# Epoch: 71 	Training Loss: 1.663594 	Validation Loss: 1.412622
# Epoch 72, Batch 1 loss: 1.478322
# Epoch 72, Batch 101 loss: 1.583774
# Epoch 72, Batch 201 loss: 1.647079
# Epoch 72, Batch 301 loss: 1.648178
# Epoch: 72 	Training Loss: 1.644443 	Validation Loss: 1.270692
# Validation loss decreased (1.391624 --> 1.270692).  Saving model ...
# Epoch 73, Batch 1 loss: 1.210324
# Epoch 73, Batch 101 loss: 1.595611
# Epoch 73, Batch 201 loss: 1.635939
# Epoch 73, Batch 301 loss: 1.669298
# Epoch: 73 	Training Loss: 1.663634 	Validation Loss: 1.302143
# Epoch 74, Batch 1 loss: 1.210172
# Epoch 74, Batch 101 loss: 1.563189
# Epoch 74, Batch 201 loss: 1.589892
# Epoch 74, Batch 301 loss: 1.631247
# Epoch: 74 	Training Loss: 1.633336 	Validation Loss: 1.208604
# Validation loss decreased (1.270692 --> 1.208604).  Saving model ...
# Epoch 75, Batch 1 loss: 1.440583
# Epoch 75, Batch 101 loss: 1.508263
# Epoch 75, Batch 201 loss: 1.533514
# Epoch 75, Batch 301 loss: 1.585436
# Epoch: 75 	Training Loss: 1.581718 	Validation Loss: 1.239969
# Epoch 76, Batch 1 loss: 1.143539
# Epoch 76, Batch 101 loss: 1.559632
# Epoch 76, Batch 201 loss: 1.645388
# Epoch 76, Batch 301 loss: 1.654033
# Epoch: 76 	Training Loss: 1.649325 	Validation Loss: 1.325334
# Epoch 77, Batch 1 loss: 1.463963
# Epoch 77, Batch 101 loss: 1.557049
# Epoch 77, Batch 201 loss: 1.558979
# Epoch 77, Batch 301 loss: 1.595133
# Epoch: 77 	Training Loss: 1.603731 	Validation Loss: 1.348989
# Epoch 78, Batch 1 loss: 2.170935
# Epoch 78, Batch 101 loss: 1.484934
# Epoch 78, Batch 201 loss: 1.507336
# Epoch 78, Batch 301 loss: 1.541487
# Epoch: 78 	Training Loss: 1.554685 	Validation Loss: 1.275529
# Epoch 79, Batch 1 loss: 1.222883
# Epoch 79, Batch 101 loss: 1.422460
# Epoch 79, Batch 201 loss: 1.464554
# Epoch 79, Batch 301 loss: 1.529997
# Epoch: 79 	Training Loss: 1.540022 	Validation Loss: 1.305354
# Epoch 80, Batch 1 loss: 1.111486
# Epoch 80, Batch 101 loss: 1.452455
# Epoch 80, Batch 201 loss: 1.516398
# Epoch 80, Batch 301 loss: 1.537584
# Epoch: 80 	Training Loss: 1.546152 	Validation Loss: 1.244234
# Epoch 81, Batch 1 loss: 1.219265
# Epoch 81, Batch 101 loss: 1.522839
# Epoch 81, Batch 201 loss: 1.512205
# Epoch 81, Batch 301 loss: 1.504129
# Epoch: 81 	Training Loss: 1.513360 	Validation Loss: 1.214943
# Epoch 82, Batch 1 loss: 1.733685
# Epoch 82, Batch 101 loss: 1.429607
# Epoch 82, Batch 201 loss: 1.463293
# Epoch 82, Batch 301 loss: 1.468225
# Epoch: 82 	Training Loss: 1.463262 	Validation Loss: 1.133409
# Validation loss decreased (1.208604 --> 1.133409).  Saving model ...
# Epoch 83, Batch 1 loss: 1.096385
# Epoch 83, Batch 101 loss: 1.409035
# Epoch 83, Batch 201 loss: 1.475679
# Epoch 83, Batch 301 loss: 1.475566
# Epoch: 83 	Training Loss: 1.482561 	Validation Loss: 1.182492
# Epoch 84, Batch 1 loss: 1.738069
# Epoch 84, Batch 101 loss: 1.427671
# Epoch 84, Batch 201 loss: 1.479524
# Epoch 84, Batch 301 loss: 1.494538
# Epoch: 84 	Training Loss: 1.501009 	Validation Loss: 1.216980
# Epoch 85, Batch 1 loss: 1.600912
# Epoch 85, Batch 101 loss: 1.446045
# Epoch 85, Batch 201 loss: 1.497705
# Epoch 85, Batch 301 loss: 1.484409
# Epoch: 85 	Training Loss: 1.475324 	Validation Loss: 1.106650
# Validation loss decreased (1.133409 --> 1.106650).  Saving model ...
# Epoch 86, Batch 1 loss: 1.733646
# Epoch 86, Batch 101 loss: 1.406216
# Epoch 86, Batch 201 loss: 1.418853
# Epoch 86, Batch 301 loss: 1.428488
# Epoch: 86 	Training Loss: 1.425697 	Validation Loss: 1.157238
# Epoch 87, Batch 1 loss: 1.843190
# Epoch 87, Batch 101 loss: 1.415286
# Epoch 87, Batch 201 loss: 1.434396
# Epoch 87, Batch 301 loss: 1.456519
# Epoch: 87 	Training Loss: 1.454699 	Validation Loss: 1.228800
# Epoch 88, Batch 1 loss: 2.351066
# Epoch 88, Batch 101 loss: 1.427306
# Epoch 88, Batch 201 loss: 1.400261
# Epoch 88, Batch 301 loss: 1.406387
# Epoch: 88 	Training Loss: 1.403057 	Validation Loss: 1.145245
# Epoch 89, Batch 1 loss: 0.855994
# Epoch 89, Batch 101 loss: 1.336708
# Epoch 89, Batch 201 loss: 1.382252
# Epoch 89, Batch 301 loss: 1.391109
# Epoch: 89 	Training Loss: 1.396023 	Validation Loss: 1.195057
# Epoch 90, Batch 1 loss: 0.854364
# Epoch 90, Batch 101 loss: 1.369317
# Epoch 90, Batch 201 loss: 1.414954
# Epoch 90, Batch 301 loss: 1.416039
# Epoch: 90 	Training Loss: 1.418030 	Validation Loss: 1.044704
# Validation loss decreased (1.106650 --> 1.044704).  Saving model ...
# Epoch 91, Batch 1 loss: 1.842992
# Epoch 91, Batch 101 loss: 1.294455
# Epoch 91, Batch 201 loss: 1.311877
# Epoch 91, Batch 301 loss: 1.334322
# Epoch: 91 	Training Loss: 1.346790 	Validation Loss: 1.064767
# Epoch 92, Batch 1 loss: 1.018677
# Epoch 92, Batch 101 loss: 1.349483
# Epoch 92, Batch 201 loss: 1.356899
# Epoch 92, Batch 301 loss: 1.370629
# Epoch: 92 	Training Loss: 1.377057 	Validation Loss: 1.101143
# Epoch 93, Batch 1 loss: 1.960780
# Epoch 93, Batch 101 loss: 1.317698
# Epoch 93, Batch 201 loss: 1.342713
# Epoch 93, Batch 301 loss: 1.378106
# Epoch: 93 	Training Loss: 1.373695 	Validation Loss: 1.056177
# Epoch 94, Batch 1 loss: 0.740653
# Epoch 94, Batch 101 loss: 1.271169
# Epoch 94, Batch 201 loss: 1.299203
# Epoch 94, Batch 301 loss: 1.330028
# Epoch: 94 	Training Loss: 1.320322 	Validation Loss: 1.012445
# Validation loss decreased (1.044704 --> 1.012445).  Saving model ...
# Epoch 95, Batch 1 loss: 0.933825
# Epoch 95, Batch 101 loss: 1.290272
# Epoch 95, Batch 201 loss: 1.326828
# Epoch 95, Batch 301 loss: 1.370877
# Epoch: 95 	Training Loss: 1.366876 	Validation Loss: 1.078523
# Epoch 96, Batch 1 loss: 0.803236
# Epoch 96, Batch 101 loss: 1.330773
# Epoch 96, Batch 201 loss: 1.301494
# Epoch 96, Batch 301 loss: 1.345965
# Epoch: 96 	Training Loss: 1.352013 	Validation Loss: 0.994745
# Validation loss decreased (1.012445 --> 0.994745).  Saving model ...
# Epoch 97, Batch 1 loss: 1.381789
# Epoch 97, Batch 101 loss: 1.332599
# Epoch 97, Batch 201 loss: 1.331812
# Epoch 97, Batch 301 loss: 1.344240
# Epoch: 97 	Training Loss: 1.338630 	Validation Loss: 1.015234
# Epoch 98, Batch 1 loss: 1.285825
# Epoch 98, Batch 101 loss: 1.352787
# Epoch 98, Batch 201 loss: 1.331273
# Epoch 98, Batch 301 loss: 1.354986
# Epoch: 98 	Training Loss: 1.347481 	Validation Loss: 1.054617
# Epoch 99, Batch 1 loss: 1.099705
# Epoch 99, Batch 101 loss: 1.271226
# Epoch 99, Batch 201 loss: 1.301725
# Epoch 99, Batch 301 loss: 1.305341
# Epoch: 99 	Training Loss: 1.304075 	Validation Loss: 1.010746
# Epoch 100, Batch 1 loss: 0.989347
# Epoch 100, Batch 101 loss: 1.308524
# Epoch 100, Batch 201 loss: 1.269442
# Epoch 100, Batch 301 loss: 1.316943
# Epoch: 100 	Training Loss: 1.320776 	Validation Loss: 1.140053
# <All keys matched successfully>

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images.  Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 10%.

# %%
def test(loaders, model, criterion, use_cuda):

    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.

    model.eval()
    for batch_idx, (data, target) in enumerate(loaders['test']):
        # move to GPU
        if use_cuda:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update average test loss 
        test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
        # convert output probabilities to predicted class
        pred = output.data.max(1, keepdim=True)[1]
        # compare predictions to true label
        correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
        total += data.size(0)
            
    print('Test Loss: {:.6f}\n'.format(test_loss))

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (
        100. * correct / total, correct, total))

# call test function    
test(loaders_scratch, model_scratch, criterion_scratch, use_cuda)
# Out:
# Test Loss: 1.004143
#
#
# Test Accuracy: 75% (5050/6680)

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/master/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dogImages/train`, `dogImages/valid`, and `dogImages/test`, respectively).
#
# If you like, **you are welcome to use the same data loaders from the previous step**, when you created a CNN from scratch.

# %%
## TODO: Specify data loaders
root_dir = 'data/dogImages/'
train_dir = os.path.join(root_dir, 'train/')
valid_dir = os.path.join(root_dir, 'valid/')
test_dir = os.path.join(root_dir, 'test/')

normalization = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])

train_transform = transforms.Compose([transforms.Resize(256),
                                      transforms.RandomResizedCrop(224),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.RandomRotation(10),
                                      transforms.ToTensor(),
                                      normalization])

valid_transform = transforms.Compose([transforms.Resize(256), 
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      normalization])

test_transform  = transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      normalization])

batch_size = 20
num_workers = 0

train_data = datasets.ImageFolder(train_dir, transform=train_transform)
valid_data = datasets.ImageFolder(valid_dir, transform=valid_transform)
test_data = datasets.ImageFolder(test_dir, transform=test_transform)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=num_workers)

loaders_transfer = {"train" : train_loader, "valid" : valid_loader, "test" : test_loader}

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Use transfer learning to create a CNN to classify dog breed.  Use the code cell below, and save your initialized model as the variable `model_transfer`.

# %%
import torchvision.models as models
import torch.nn as nn

## TODO: Specify model architecture 
model_transfer = models.resnext101_32x8d(pretrained=True)
model_transfer.add_module('drop', nn.Dropout(0.3))
model_transfer.add_module('fc1', nn.Linear(in_features=1000, out_features=134, bias=True))

# Freeze training for all parameters
for param in model_transfer.parameters():
    param.requires_grad = False

# Replacing the last 3 layers for fine tuning
# Parameters of newly constructed modules have requires_grad=True by default
model_transfer.fc = nn.Linear(2048, 1000, bias=True)
model_transfer.drop = nn.Dropout(0.3)
model_transfer.fc1 = nn.Linear(in_features=1000, out_features=134, bias=True)


if use_cuda:
    model_transfer = model_transfer.cuda()

# %% [markdown]
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.

# %% [markdown]
# __Answer:__

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/master/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/master/optim.html).  Save the chosen loss function as `criterion_transfer`, and the optimizer as `optimizer_transfer` below.

# %%
criterion_transfer = nn.CrossEntropyLoss()
optimizer_transfer = optim.SGD(model_transfer.fc.parameters(), lr=0.01, momentum=0.9)

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_transfer.pt'`.

# %%
# train the model
model_transfer = train(40, loaders_transfer, model_transfer, optimizer_transfer, criterion_transfer, use_cuda, 'model_transfer.pt')

# load the model that got the best validation accuracy (uncomment the line below)
#model_transfer.load_state_dict(torch.load('model_transfer.pt'))
# Out:
# Epoch 1, Batch 1 loss: 6.990724
# Epoch 1, Batch 101 loss: 3.806520
# Epoch 1, Batch 201 loss: 2.782044
# Epoch 1, Batch 301 loss: 2.322669
# Epoch: 1 	Training Loss: 2.218356 	Validation Loss: 1.017942
# Validation loss decreased (inf --> 1.017942).  Saving model ...
# Epoch 2, Batch 1 loss: 1.216702
# Epoch 2, Batch 101 loss: 1.133730
# Epoch 2, Batch 201 loss: 1.139048
# Epoch 2, Batch 301 loss: 1.104791
# Epoch: 2 	Training Loss: 1.105480 	Validation Loss: 0.941831
# Validation loss decreased (1.017942 --> 0.941831).  Saving model ...
# Epoch 3, Batch 1 loss: 1.122338
# Epoch 3, Batch 101 loss: 0.978214
# Epoch 3, Batch 201 loss: 0.973703
# Epoch 3, Batch 301 loss: 0.978466
# Epoch: 3 	Training Loss: 0.982591 	Validation Loss: 0.790056
# Validation loss decreased (0.941831 --> 0.790056).  Saving model ...
# Epoch 4, Batch 1 loss: 1.248012
# Epoch 4, Batch 101 loss: 0.898077
# Epoch 4, Batch 201 loss: 0.899665
# Epoch 4, Batch 301 loss: 0.898802
# Epoch: 4 	Training Loss: 0.905631 	Validation Loss: 0.751284
# Validation loss decreased (0.790056 --> 0.751284).  Saving model ...
# Epoch 5, Batch 1 loss: 1.135782
# Epoch 5, Batch 101 loss: 0.913780
# Epoch 5, Batch 201 loss: 0.873728
# Epoch 5, Batch 301 loss: 0.878040
# Epoch: 5 	Training Loss: 0.875449 	Validation Loss: 0.782629
# Epoch 6, Batch 1 loss: 0.375945
# Epoch 6, Batch 101 loss: 0.832622
# Epoch 6, Batch 201 loss: 0.855785
# Epoch 6, Batch 301 loss: 0.868267
# Epoch: 6 	Training Loss: 0.849248 	Validation Loss: 0.690308
# Validation loss decreased (0.751284 --> 0.690308).  Saving model ...
# Epoch 7, Batch 1 loss: 1.112209
# Epoch 7, Batch 101 loss: 0.826539
# Epoch 7, Batch 201 loss: 0.824545
# Epoch 7, Batch 301 loss: 0.850441
# Epoch: 7 	Training Loss: 0.837701 	Validation Loss: 0.726040
# Epoch 8, Batch 1 loss: 1.129323
# Epoch 8, Batch 101 loss: 0.797402
# Epoch 8, Batch 201 loss: 0.802284
# Epoch 8, Batch 301 loss: 0.812251
# Epoch: 8 	Training Loss: 0.805445 	Validation Loss: 0.649322
# Validation loss decreased (0.690308 --> 0.649322).  Saving model ...
# Epoch 9, Batch 1 loss: 1.443608
# Epoch 9, Batch 101 loss: 0.784585
# Epoch 9, Batch 201 loss: 0.785625
# Epoch 9, Batch 301 loss: 0.784004
# Epoch: 9 	Training Loss: 0.784194 	Validation Loss: 0.652505
# Epoch 10, Batch 1 loss: 0.636334
# Epoch 10, Batch 101 loss: 0.752914
# Epoch 10, Batch 201 loss: 0.761945
# Epoch 10, Batch 301 loss: 0.740525
# Epoch: 10 	Training Loss: 0.741949 	Validation Loss: 0.632956
# Validation loss decreased (0.649322 --> 0.632956).  Saving model ...
# Epoch 11, Batch 1 loss: 0.531080
# Epoch 11, Batch 101 loss: 0.777720
# Epoch 11, Batch 201 loss: 0.792546
# Epoch 11, Batch 301 loss: 0.787908
# Epoch: 11 	Training Loss: 0.786175 	Validation Loss: 0.594805
# Validation loss decreased (0.632956 --> 0.594805).  Saving model ...
# Epoch 12, Batch 1 loss: 0.847756
# Epoch 12, Batch 101 loss: 0.741071
# Epoch 12, Batch 201 loss: 0.739461
# Epoch 12, Batch 301 loss: 0.743468
# Epoch: 12 	Training Loss: 0.747385 	Validation Loss: 0.584937
# Validation loss decreased (0.594805 --> 0.584937).  Saving model ...
# Epoch 13, Batch 1 loss: 0.977831
# Epoch 13, Batch 101 loss: 0.695429
# Epoch 13, Batch 201 loss: 0.728211
# Epoch 13, Batch 301 loss: 0.738595
# Epoch: 13 	Training Loss: 0.739333 	Validation Loss: 0.602403
# Epoch 14, Batch 1 loss: 0.326327
# Epoch 14, Batch 101 loss: 0.680974
# Epoch 14, Batch 201 loss: 0.683953
# Epoch 14, Batch 301 loss: 0.701022
# Epoch: 14 	Training Loss: 0.702699 	Validation Loss: 0.569870
# Validation loss decreased (0.584937 --> 0.569870).  Saving model ...
# Epoch 15, Batch 1 loss: 0.862034
# Epoch 15, Batch 101 loss: 0.675533
# Epoch 15, Batch 201 loss: 0.710772
# Epoch 15, Batch 301 loss: 0.730438
# Epoch: 15 	Training Loss: 0.732559 	Validation Loss: 0.608354
# Epoch 16, Batch 1 loss: 1.025555
# Epoch 16, Batch 101 loss: 0.674522
# Epoch 16, Batch 201 loss: 0.713231
# Epoch 16, Batch 301 loss: 0.726528
# Epoch: 16 	Training Loss: 0.726983 	Validation Loss: 0.623270
# Epoch 17, Batch 1 loss: 1.527047
# Epoch 17, Batch 101 loss: 0.753390
# Epoch 17, Batch 201 loss: 0.713872
# Epoch 17, Batch 301 loss: 0.719733
# Epoch: 17 	Training Loss: 0.717792 	Validation Loss: 0.580160
# Epoch 18, Batch 1 loss: 0.436242
# Epoch 18, Batch 101 loss: 0.676008
# Epoch 18, Batch 201 loss: 0.667410
# Epoch 18, Batch 301 loss: 0.686484
# Epoch: 18 	Training Loss: 0.689225 	Validation Loss: 0.650303
# Epoch 19, Batch 1 loss: 0.582345
# Epoch 19, Batch 101 loss: 0.670293
# Epoch 19, Batch 201 loss: 0.710453
# Epoch 19, Batch 301 loss: 0.686460
# Epoch: 19 	Training Loss: 0.683142 	Validation Loss: 0.584868
# Epoch 20, Batch 1 loss: 0.905900
# Epoch 20, Batch 101 loss: 0.669709
# Epoch 20, Batch 201 loss: 0.665804
# Epoch 20, Batch 301 loss: 0.665328
# Epoch: 20 	Training Loss: 0.646043 	Validation Loss: 0.569075
# Validation loss decreased (0.569870 --> 0.569075).  Saving model ...
# Epoch 21, Batch 1 loss: 0.942723
# Epoch 21, Batch 101 loss: 0.640253
# Epoch 21, Batch 201 loss: 0.696203
# Epoch 21, Batch 301 loss: 0.691843
# Epoch: 21 	Training Loss: 0.677062 	Validation Loss: 0.577302
# Epoch 22, Batch 1 loss: 0.515316
# Epoch 22, Batch 101 loss: 0.618863
# Epoch 22, Batch 201 loss: 0.668686
# Epoch 22, Batch 301 loss: 0.680856
# Epoch: 22 	Training Loss: 0.684523 	Validation Loss: 0.595943
# Epoch 23, Batch 1 loss: 0.492814
# Epoch 23, Batch 101 loss: 0.619390
# Epoch 23, Batch 201 loss: 0.661426
# Epoch 23, Batch 301 loss: 0.639645
# Epoch: 23 	Training Loss: 0.651161 	Validation Loss: 0.566066
# Validation loss decreased (0.569075 --> 0.566066).  Saving model ...
# Epoch 24, Batch 1 loss: 0.899573
# Epoch 24, Batch 101 loss: 0.658039
# Epoch 24, Batch 201 loss: 0.656700
# Epoch 24, Batch 301 loss: 0.663664
# Epoch: 24 	Training Loss: 0.660058 	Validation Loss: 0.520823
# Validation loss decreased (0.566066 --> 0.520823).  Saving model ...
# Epoch 25, Batch 1 loss: 0.354453
# Epoch 25, Batch 101 loss: 0.666772
# Epoch 25, Batch 201 loss: 0.667751
# Epoch 25, Batch 301 loss: 0.666232
# Epoch: 25 	Training Loss: 0.669876 	Validation Loss: 0.554046
# Epoch 26, Batch 1 loss: 1.180292
# Epoch 26, Batch 101 loss: 0.615195
# Epoch 26, Batch 201 loss: 0.628188
# Epoch 26, Batch 301 loss: 0.644114
# Epoch: 26 	Training Loss: 0.641607 	Validation Loss: 0.542479
# Epoch 27, Batch 1 loss: 0.588239
# Epoch 27, Batch 101 loss: 0.653884
# Epoch 27, Batch 201 loss: 0.652110
# Epoch 27, Batch 301 loss: 0.659306
# Epoch: 27 	Training Loss: 0.660084 	Validation Loss: 0.542720
# Epoch 28, Batch 1 loss: 0.135414
# Epoch 28, Batch 101 loss: 0.594512
# Epoch 28, Batch 201 loss: 0.638902
# Epoch 28, Batch 301 loss: 0.648933
# Epoch: 28 	Training Loss: 0.653738 	Validation Loss: 0.578708
# Epoch 29, Batch 1 loss: 0.698461
# Epoch 29, Batch 101 loss: 0.612480
# Epoch 29, Batch 201 loss: 0.616801
# Epoch 29, Batch 301 loss: 0.625922
# Epoch: 29 	Training Loss: 0.634020 	Validation Loss: 0.543082
# Epoch 30, Batch 1 loss: 0.706908
# Epoch 30, Batch 101 loss: 0.658204
# Epoch 30, Batch 201 loss: 0.648835
# Epoch 30, Batch 301 loss: 0.645490
# Epoch: 30 	Training Loss: 0.652383 	Validation Loss: 0.535321
# Epoch 31, Batch 1 loss: 0.269095
# Epoch 31, Batch 101 loss: 0.662322
# Epoch 31, Batch 201 loss: 0.674149
# Epoch 31, Batch 301 loss: 0.674523
# Epoch: 31 	Training Loss: 0.671107 	Validation Loss: 0.552682
# Epoch 32, Batch 1 loss: 0.316524
# Epoch 32, Batch 101 loss: 0.604501
# Epoch 32, Batch 201 loss: 0.623590
# Epoch 32, Batch 301 loss: 0.647054
# Epoch: 32 	Training Loss: 0.652695 	Validation Loss: 0.502153
# Validation loss decreased (0.520823 --> 0.502153).  Saving model ...
# Epoch 33, Batch 1 loss: 0.176496
# Epoch 33, Batch 101 loss: 0.612325
# Epoch 33, Batch 201 loss: 0.617676
# Epoch 33, Batch 301 loss: 0.644404
# Epoch: 33 	Training Loss: 0.646788 	Validation Loss: 0.480033
# Validation loss decreased (0.502153 --> 0.480033).  Saving model ...
# Epoch 34, Batch 1 loss: 0.585840
# Epoch 34, Batch 101 loss: 0.672453
# Epoch 34, Batch 201 loss: 0.623030
# Epoch 34, Batch 301 loss: 0.616183
# Epoch: 34 	Training Loss: 0.615012 	Validation Loss: 0.537998
# Epoch 35, Batch 1 loss: 0.678560
# Epoch 35, Batch 101 loss: 0.646986
# Epoch 35, Batch 201 loss: 0.612562
# Epoch 35, Batch 301 loss: 0.611861
# Epoch: 35 	Training Loss: 0.620161 	Validation Loss: 0.534590
# Epoch 36, Batch 1 loss: 0.420996
# Epoch 36, Batch 101 loss: 0.639736
# Epoch 36, Batch 201 loss: 0.611540
# Epoch 36, Batch 301 loss: 0.600554
# Epoch: 36 	Training Loss: 0.603632 	Validation Loss: 0.507064
# Epoch 37, Batch 1 loss: 0.930754
# Epoch 37, Batch 101 loss: 0.708649
# Epoch 37, Batch 201 loss: 0.686431
# Epoch 37, Batch 301 loss: 0.666432
# Epoch: 37 	Training Loss: 0.670378 	Validation Loss: 0.500598
# Epoch 38, Batch 1 loss: 1.039207
# Epoch 38, Batch 101 loss: 0.668366
# Epoch 38, Batch 201 loss: 0.668854
# Epoch 38, Batch 301 loss: 0.658226
# Epoch: 38 	Training Loss: 0.646943 	Validation Loss: 0.516217
# Epoch 39, Batch 1 loss: 0.608278
# Epoch 39, Batch 101 loss: 0.573791
# Epoch 39, Batch 201 loss: 0.586296
# Epoch 39, Batch 301 loss: 0.610351
# Epoch: 39 	Training Loss: 0.609405 	Validation Loss: 0.512284
# Epoch 40, Batch 1 loss: 0.778040
# Epoch 40, Batch 101 loss: 0.585878
# Epoch 40, Batch 201 loss: 0.585226
# Epoch 40, Batch 301 loss: 0.599687
# Epoch: 40 	Training Loss: 0.602213 	Validation Loss: 0.519859

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 60%.

# %%
test(loaders_transfer, model_transfer, criterion_transfer, use_cuda)
# Out:
# Test Loss: 0.501793
#
#
# Test Accuracy: 86% (5773/6680)

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan hound`, etc) that is predicted by your model.

# %%
from torch.autograd import Variable
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.
data_transfer = loaders_transfer
# list of class names by index, i.e. a name can be accessed like class_names[0]
class_names = [item[4:].replace("_", " ") for item in data_transfer['train'].dataset.classes]

def predict_breed_transfer(img_path, model, topk):
    '''
    A function that takes a path to an image as input
    and returns top-k predictions of the dog breed that is predicted by the model.
        
    Args:
        img_path: path to an image
        model:    model for prediction
        topk:     desired top-k-numbers of predictions
    Returns:
        Returns top-k predictions and top-k labels in an array
    '''
    
    # Define image transformation
    # Define standard normalization for all transormations as used in training
    normalization = transforms.Normalize(mean=[0.485, 0.456, 0.406],         # Normalizing the image with specific mean and standard deviation
                                          std=[0.229, 0.224, 0.225])
    transformation = transforms.Compose([transforms.Resize(256),             # Resize the image to 256x256 pixels
                                         transforms.CenterCrop(224),         # Crops the given Image at the center to 224x224 pixels
                                         transforms.ToTensor(),              # Convert the image to the PyTorch Tensor data type
                                         normalization])
    
    # If Cuda-enabled GPU is available, use it. If not, use CPU
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    # Put model to evaluation mode
    model.eval()
    
    # Load image
    img = Image.open(img_path).convert('RGB')
    # Transform image
    img = transformation(img).float()
    # Change Tensor to a one-dimensional one
    img = img.unsqueeze(0)
    # Convert img to a Variable. A PyTorch Variable is a wrapper around a PyTorch Tensor.
    img = Variable(img)
    # If cuda then transform img to CUDA-Datatype else CPU-Datatype
    img = img.to(device)
    # Get prediction
    prediction = model(img)
    # Convert prediction to related index
    index = prediction.data.cpu().numpy().argmax()
    
    # Get Top-k predictions, default is 3
    topk_predictions = torch.topk(prediction, topk)
    
    # Use Softmax function to extract probabilities
    soft = nn.Softmax(dim=1)
    topk_probabilities = soft(topk_predictions.values).cpu().detach().numpy()[0]
    
    # Get Top-k indices
    topk_indices = topk_predictions.indices.cpu().detach().numpy()[0]
    topk_labels = [class_names[k] for k in topk_indices]

    # return class_name
    return [topk_probabilities, topk_labels]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `human_detector` functions developed above.  You are __required__ to use your CNN from Step 4 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.

def load_image(img_path):
    img = Image.open(img_path)
    plt.imshow(img)
    plt.show()
    
def run_app(img_path, model, topk=3):
    ## handle cases for a human face, dog, and neither
   
    # Show image
    load_image(img_path)
    
    dog_detected = False
    human_detected = False
    
    # Set limits for top-k
    if topk > 10:
        topk = 10
    if topk < 1:
        topk = 1
    
    # Detect dog or human
    if dog_detector(img_path):
        dog_detected = True
        print('Hello dog! Here are the predictions for your dog breed')
    elif face_detector(img_path):
        human_detected = True
        print('Hello human! If you were a dog, you could look like')
    else:
        print('Oh... No dog or human could be identified.')
    
    # Get and print predictions
    if dog_detected or human_detected:
        topk_predictions = predict_breed_transfer(img_path, model, topk)
        for k in range(topk):
            print('Top {0:2} prediction:{1:7.2f}% - {2}'.format(k+1, topk_predictions[0][k]*100, topk_predictions[1][k]))

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that _you_ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.

# %% [markdown]
# __Answer:__ (Three possible points for improvement)

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.

## suggested code, below
for file in np.hstack((human_files[:3], dog_files[:3])):
    run_app(file, model_transfer, topk=3)
# Out:
# Hello human! If you were a dog, you could look like
# Top  1 prediction:  95.30% - Dachshund
# Top  2 prediction:   3.46% - American staffordshire terrier
# Top  3 prediction:   1.24% - Dandie dinmont terrier
# Hello human! If you were a dog, you could look like
# Top  1 prediction:  66.97% - Australian shepherd
# Top  2 prediction:  23.05% - Canaan dog
# Top  3 prediction:   9.97% - Akita
# Hello human! If you were a dog, you could look like
# Top  1 prediction:  61.81% - American staffordshire terrier
# Top  2 prediction:  28.90% - Australian shepherd
# Top  3 prediction:   9.29% - Canaan dog
# Hello dog! Here are the predictions for your dog breed
# Top  1 prediction: 100.00% - Curly-coated retriever
# Top  2 prediction:   0.00% - American water spaniel
# Top  3 prediction:   0.00% - Chesapeake bay retriever
# Hello dog! Here are the predictions for your dog breed
# Top  1 prediction:  99.92% - Curly-coated retriever
# Top  2 prediction:   0.07% - Chesapeake bay retriever
# Top  3 prediction:   0.01% - American water spaniel
# Hello dog! Here are the predictions for your dog breed
# Top  1 prediction: 100.00% - Curly-coated retriever
# Top  2 prediction:   0.00% - Irish water spaniel
# Top  3 prediction:   0.00% - Portuguese water dog
